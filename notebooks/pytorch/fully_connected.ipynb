# %% [markdown]
# # Fully-connected neural network retrieval
#
# This notebook implements a precipitation retrieval for the IPWG SPR dataset based on a convolutional neural network implemented using PyTorch and Lightning.

# %% [markdown]
# > **NOTE**: This notebook can be run on Google Colab. To install the necessary dependencies uncomment the following cell and execute it.

# %%
# %load_ext autoreload
# %autoreload 2
#!pip install git+https://github.com/simonpf/ipwgml#ipwgml[complete]

# %% [markdown]
# ## The training data
#
# The ``ipwgml`` package provides dataset classes that take care of downloading, preprocessing and loading of the SPR training data. The ``ipwgml.pytorch.dataset.SPRTabular`` class implements the PyTorch dataset interface for the SPR data in tabular format, i.e., for pixel-based retrievals.

# %% [markdown]
# The retrieval input data to load and the quality criteria for the reference surface precipitation data can be configured using the ``InputConfig`` classes from the ``ipwgml.input`` module and the ``TargetConfig`` class from the ``ipgml.target`` module, respectively.
#
# For this example notebook we use only GMI observations as input. We configure the ``GMI`` input to not include the earth-incidence angles. Moreover, enable minimum-maximum normalization of the input and replace NAN values with -1.5.
#
# > **NOTE**: Both input and reference data in the SPR dataset may contain NANs because observations or precipitation estimates may be missing or of insufficient quality. It is up to the user to handle those.
#
# We choose the ``on_swath`` geometry for the retrieval, which is a natural choice for pixel-based retrievals. We also set up batching in the dataset, which is more efficient for tabular data than leaving it to the PyTorch data loader to perform the batching.

# %%
from ipwgml.input import GMI, Ancillary, Geo, GeoIR
from ipwgml.target import TargetConfig

target_config = TargetConfig(min_rqi=0.5)
inputs = [GeoIR(normalize="minmax", nan=-1.5)]
geometry = "gridded"
batch_size = 1024

# %%
from ipwgml.config import get_data_path
from ipwgml.data import get_local_files
files = get_local_files("spr", "gmi", "on_swath", "training")
get_data_path()
files
# Out:
# {'gmi': [PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/07/gmi_20180107211849.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/09/gmi_20180109194023.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/12/gmi_20180112033237.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/17/gmi_20180117190250.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/19/gmi_20180119234805.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/23/gmi_20180123165400.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/23/gmi_20180123165747.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/24/gmi_20180124010436.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/24/gmi_20180124023319.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/26/gmi_20180126190612.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/28/gmi_20180128004033.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/28/gmi_20180128234817.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/29/gmi_20180129132104.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/30/gmi_20180130140409.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/30/gmi_20180130233817.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/01/31/gmi_20180131162106.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/05/gmi_20180205200517.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/06/gmi_20180206141548.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/08/gmi_20180208123213.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/09/gmi_20180209100936.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/09/gmi_20180209131731.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/12/gmi_20180212090523.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/12/gmi_20180212184617.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/12/gmi_20180212202351.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/13/gmi_20180213192921.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/24/gmi_20180224075818.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/24/gmi_20180224143613.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/26/gmi_20180226074800.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/26/gmi_20180226155351.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/27/gmi_20180227065601.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/02/28/gmi_20180228141333.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/05/gmi_20180305062853.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/07/gmi_20180307030742.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/09/gmi_20180309124109.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/12/gmi_20180312100353.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/12/gmi_20180312114044.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/13/gmi_20180313091202.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/14/gmi_20180314032457.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/14/gmi_20180314095516.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/21/gmi_20180321220111.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/22/gmi_20180322011431.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/22/gmi_20180322074643.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/25/gmi_20180325214624.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/27/gmi_20180327213227.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/28/gmi_20180328053919.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/28/gmi_20180328221813.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/28/gmi_20180328222020.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/29/gmi_20180329044717.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/03/29/gmi_20180329075249.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/05/gmi_20180405183215.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/06/gmi_20180406174348.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/06/gmi_20180406191057.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/08/gmi_20180408173122.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/08/gmi_20180408173256.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/08/gmi_20180408190743.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/08/gmi_20180408204332.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/09/gmi_20180409031306.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/12/gmi_20180412034247.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/12/gmi_20180412171510.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/13/gmi_20180413161850.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/15/gmi_20180415143547.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/16/gmi_20180416014840.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/18/gmi_20180418133839.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/22/gmi_20180422162007.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/22/gmi_20180422211808.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/24/gmi_20180424143454.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/26/gmi_20180426205410.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/27/gmi_20180427231436.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/28/gmi_20180428124153.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/28/gmi_20180428235531.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/29/gmi_20180429145617.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/04/30/gmi_20180430203844.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/05/gmi_20180505124931.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/05/gmi_20180505192403.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/09/gmi_20180509075335.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/11/gmi_20180511154556.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/12/gmi_20180512175345.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/13/gmi_20180513072542.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/13/gmi_20180513170553.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/13/gmi_20180513171257.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/16/gmi_20180516160449.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/16/gmi_20180516174031.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/17/gmi_20180517053331.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/17/gmi_20180517071228.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/17/gmi_20180517151717.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/19/gmi_20180519163855.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/22/gmi_20180522123150.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/22/gmi_20180522153639.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/24/gmi_20180524122237.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/25/gmi_20180525144227.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/29/gmi_20180529030337.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/29/gmi_20180529044218.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/05/29/gmi_20180529111303.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/05/gmi_20180605081746.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/05/gmi_20180605112112.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/05/gmi_20180605232403.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/06/gmi_20180606085947.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/08/gmi_20180608021430.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/08/gmi_20180608102134.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/10/gmi_20180610084310.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/11/gmi_20180611092007.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/15/gmi_20180615090524.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/15/gmi_20180615223434.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/16/gmi_20180616000617.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/17/gmi_20180617085553.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/18/gmi_20180618062531.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/19/gmi_20180619084228.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/20/gmi_20180620195019.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/24/gmi_20180624025343.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/24/gmi_20180624192835.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/24/gmi_20180624192901.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/06/30/gmi_20180630005139.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/05/gmi_20180705161900.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/06/gmi_20180706015417.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/06/gmi_20180706152550.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/08/gmi_20180708031657.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/12/gmi_20180712131641.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/15/gmi_20180715232847.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/16/gmi_20180716160706.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/17/gmi_20180717151313.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/19/gmi_20180719115407.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/20/gmi_20180720222037.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/24/gmi_20180724104503.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/25/gmi_20180725112458.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/26/gmi_20180726085744.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/27/gmi_20180727191746.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/28/gmi_20180728085048.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/07/28/gmi_20180728183008.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/05/gmi_20180805161732.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/07/gmi_20180807093336.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/08/gmi_20180808070628.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/09/gmi_20180809061047.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/10/gmi_20180810065724.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/10/gmi_20180810082649.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/10/gmi_20180810163106.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/15/gmi_20180815040655.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/19/gmi_20180819052524.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/20/gmi_20180820025753.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/24/gmi_20180824010438.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/26/gmi_20180826005803.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/27/gmi_20180827112119.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/27/gmi_20180827231427.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/28/gmi_20180828235907.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/08/30/gmi_20180830101348.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/09/gmi_20180909212310.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/10/gmi_20180910220434.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/11/gmi_20180911060749.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/11/gmi_20180911060940.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/14/gmi_20180914015828.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/16/gmi_20180916165633.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/20/gmi_20180920030817.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/20/gmi_20180920163053.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/21/gmi_20180921003816.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/22/gmi_20180922012023.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/22/gmi_20180922162046.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/22/gmi_20180922175929.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/22/gmi_20180922192924.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/24/gmi_20180924174841.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/09/26/gmi_20180926142946.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/05/gmi_20181005010143.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/05/gmi_20181005143238.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/06/gmi_20181006120409.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/06/gmi_20181006214328.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/08/gmi_20181008150502.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/09/gmi_20181009235328.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/10/gmi_20181010114306.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/10/gmi_20181010114554.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/11/gmi_20181011122852.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/12/gmi_20181012194104.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/13/gmi_20181013104052.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/14/gmi_20181014113000.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/16/gmi_20181016192108.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/18/gmi_20181018204529.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/20/gmi_20181020110210.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/20/gmi_20181020123518.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/23/gmi_20181023180716.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/25/gmi_20181025144307.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/26/gmi_20181026152323.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/29/gmi_20181029044813.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/30/gmi_20181030150437.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/30/gmi_20181030163922.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/10/31/gmi_20181031074149.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/05/gmi_20181105031810.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/06/gmi_20181106071317.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/08/gmi_20181108052632.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/08/gmi_20181108115908.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/10/gmi_20181110033915.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/10/gmi_20181110114259.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/10/gmi_20181110131921.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/11/gmi_20181111025044.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/11/gmi_20181111105413.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/15/gmi_20181115103558.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/16/gmi_20181116000721.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/17/gmi_20181117085000.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/18/gmi_20181118012438.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/19/gmi_20181119102030.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/20/gmi_20181120225300.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/21/gmi_20181121220405.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/22/gmi_20181122011020.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/23/gmi_20181123015125.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/24/gmi_20181124090613.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/25/gmi_20181125063610.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/27/gmi_20181127000023.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/28/gmi_20181128004247.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/30/gmi_20181130052916.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/11/30/gmi_20181130083414.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/06/gmi_20181206063701.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/09/gmi_20181209053244.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/11/gmi_20181211171750.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/11/gmi_20181211185111.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/11/gmi_20181211220358.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/12/gmi_20181212025804.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/12/gmi_20181212042730.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/13/gmi_20181213051248.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/13/gmi_20181213202111.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/14/gmi_20181214011557.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/15/gmi_20181215152841.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/17/gmi_20181217232327.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/18/gmi_20181218022906.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/20/gmi_20181220004129.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/20/gmi_20181220005038.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/20/gmi_20181220154948.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/20/gmi_20181220235615.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/22/gmi_20181222003340.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/22/gmi_20181222233826.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/26/gmi_20181226134319.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/26/gmi_20181226231712.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/26/gmi_20181226232408.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/27/gmi_20181227124955.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/29/gmi_20181229204605.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/30/gmi_20181230114656.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/31/gmi_20181231203843.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2018/12/31/gmi_20181231220522.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/06/gmi_20190106183319.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/08/gmi_20190108101658.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/09/gmi_20190109203405.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/11/gmi_20190111073835.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/11/gmi_20190111104328.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/13/gmi_20190113103709.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/17/gmi_20190117101440.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/17/gmi_20190117151239.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/18/gmi_20190118154659.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/20/gmi_20190120060257.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/20/gmi_20190120140620.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/21/gmi_20190121144840.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/24/gmi_20190124071911.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/25/gmi_20190125062744.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/26/gmi_20190126134508.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/27/gmi_20190127125407.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/30/gmi_20190130051453.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/30/gmi_20190130114740.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/01/30/gmi_20190130131649.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/06/gmi_20190206004736.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/06/gmi_20190206235512.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/10/gmi_20190210015936.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/11/gmi_20190211091738.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/11/gmi_20190211091951.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/12/gmi_20190212082103.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/16/gmi_20190216045750.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/16/gmi_20190216230940.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/18/gmi_20190218075528.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/18/gmi_20190218075732.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/21/gmi_20190221202225.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/22/gmi_20190222210213.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/22/gmi_20190222210516.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/22/gmi_20190222223800.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/23/gmi_20190223184427.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/24/gmi_20190224042013.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/24/gmi_20190224205408.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/26/gmi_20190226041000.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/02/28/gmi_20190228035751.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/05/gmi_20190305210025.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/06/gmi_20190306152139.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/08/gmi_20190308151509.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/11/gmi_20190311021416.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/13/gmi_20190313153816.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/14/gmi_20190314131241.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/14/gmi_20190314211504.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/15/gmi_20190315002325.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/16/gmi_20190316143132.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/16/gmi_20190316160836.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/17/gmi_20190317133909.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/17/gmi_20190317151311.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/20/gmi_20190320141106.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/22/gmi_20190322203701.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/22/gmi_20190322221249.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/22/gmi_20190322234344.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/23/gmi_20190323131212.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/25/gmi_20190325130724.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/26/gmi_20190326134851.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/26/gmi_20190326201518.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/27/gmi_20190327192605.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/30/gmi_20190330183023.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/31/gmi_20190331191023.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/03/31/gmi_20190331203725.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/05/gmi_20190405095220.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/05/gmi_20190405095428.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/07/gmi_20190407174732.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/08/gmi_20190408152211.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/10/gmi_20190410163921.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/13/gmi_20190413091135.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/14/gmi_20190414081817.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/15/gmi_20190415042159.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/16/gmi_20190416050008.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/17/gmi_20190417054042.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/18/gmi_20190418062541.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/19/gmi_20190419035237.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/21/gmi_20190421034254.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/22/gmi_20190422042915.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/26/gmi_20190426041019.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/28/gmi_20190428035834.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/28/gmi_20190428120502.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/04/29/gmi_20190429080057.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/05/gmi_20190505055844.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/08/gmi_20190508063258.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/09/gmi_20190509221324.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/10/gmi_20190510075736.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/11/gmi_20190511220408.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/13/gmi_20190513082718.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/16/gmi_20190516192550.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/19/gmi_20190519032111.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/20/gmi_20190520054001.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/27/gmi_20190527161344.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/05/31/gmi_20190531172731.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/05/gmi_20190605161458.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/07/gmi_20190607160211.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/08/gmi_20190608133806.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/10/gmi_20190610212859.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/10/gmi_20190610213122.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/11/gmi_20190611140345.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/11/gmi_20190611190234.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/13/gmi_20190613104902.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/14/gmi_20190614193413.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/14/gmi_20190614224133.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/16/gmi_20190616094152.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/19/gmi_20190619114738.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/21/gmi_20190621113912.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/21/gmi_20190621194521.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/26/gmi_20190626102747.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/26/gmi_20190626170129.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/27/gmi_20190627093252.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/06/28/gmi_20190628083849.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/07/05/gmi_20190705071902.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/07/14/gmi_20190714122822.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/07/17/gmi_20190717031609.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/07/19/gmi_20190719030758.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/07/19/gmi_20190719080454.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/07/26/gmi_20190726231612.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/05/gmi_20190805205603.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/06/gmi_20190806063550.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/06/gmi_20190806063707.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/08/gmi_20190808230234.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/14/gmi_20190814055333.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/15/gmi_20190815200618.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/17/gmi_20190817151002.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/19/gmi_20190819000154.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/19/gmi_20190819014009.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/23/gmi_20190823175048.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/24/gmi_20190824015255.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/27/gmi_20190827142348.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/28/gmi_20190828133507.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/30/gmi_20190830132113.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/08/30/gmi_20190830132339.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/07/gmi_20190907124326.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/08/gmi_20190908101844.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/09/gmi_20190909123448.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/12/gmi_20190912193716.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/15/gmi_20190915200932.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/16/gmi_20190916094308.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/17/gmi_20190917102308.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/18/gmi_20190918075229.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/20/gmi_20190920154738.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/21/gmi_20190921163026.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/22/gmi_20190922154336.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/24/gmi_20190924085556.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/26/gmi_20190926151530.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/28/gmi_20190928035519.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/09/28/gmi_20190928052621.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/05/gmi_20191005133951.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/09/gmi_20191009003117.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/09/gmi_20191009020813.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/10/gmi_20191010012101.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/10/gmi_20191010042837.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/10/gmi_20191010092312.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/11/gmi_20191011015715.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/13/gmi_20191013001716.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/13/gmi_20191013095820.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/13/gmi_20191013232432.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/20/gmi_20191020065958.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/20/gmi_20191020220031.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/22/gmi_20191022202108.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/24/gmi_20191024064326.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/25/gmi_20191025191833.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/25/gmi_20191025222934.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/26/gmi_20191026080638.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/27/gmi_20191027190602.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/28/gmi_20191028062030.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/28/gmi_20191028075449.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/29/gmi_20191029070329.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/30/gmi_20191030180555.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/30/gmi_20191030181107.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/30/gmi_20191030181403.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/10/31/gmi_20191031171423.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/05/gmi_20191105191644.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/06/gmi_20191106181849.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/07/gmi_20191107040155.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/07/gmi_20191107190640.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/08/gmi_20191108181232.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/15/gmi_20191115165122.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/17/gmi_20191117163718.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/17/gmi_20191117230337.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/18/gmi_20191118141027.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/18/gmi_20191118235105.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/19/gmi_20191119162922.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/20/gmi_20191120122802.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/20/gmi_20191120140347.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/21/gmi_20191121113327.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/21/gmi_20191121225022.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/22/gmi_20191122135137.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/22/gmi_20191122135309.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/24/gmi_20191124214217.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/26/gmi_20191126115618.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/28/gmi_20191128114314.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/28/gmi_20191128131657.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/11/29/gmi_20191129123024.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/05/gmi_20191205151737.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/06/gmi_20191206160127.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/07/gmi_20191207070424.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/07/gmi_20191207150846.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/08/gmi_20191208172142.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/10/gmi_20191210154021.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/10/gmi_20191210154155.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/10/gmi_20191210154404.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/10/gmi_20191210154455.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/12/gmi_20191212153508.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2019/12/15/gmi_20191215075658.nc'),
# ...
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/18/target_20211018001329.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/20/target_20211020001111.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/20/target_20211020094028.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/21/target_20211021004552.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/22/target_20211022013012.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/22/target_20211022030558.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/22/target_20211022093353.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/22/target_20211022094102.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/23/target_20211023234352.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/25/target_20211025233841.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/26/target_20211026010825.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/29/target_20211029081651.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/29/target_20211029231544.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/10/30/target_20211030005151.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/05/target_20211105052215.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/12/target_20211112190443.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/14/target_20211114035214.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/16/target_20211116171015.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/17/target_20211117161427.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/17/target_20211117162146.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/20/target_20211120232447.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/22/target_20211122133101.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/22/target_20211122150319.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/23/target_20211123004138.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/23/target_20211123141322.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/23/target_20211123154923.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/23/target_20211123155018.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/26/target_20211126131642.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/27/target_20211127135227.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/27/target_20211127153153.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/27/target_20211127215721.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/28/target_20211128112640.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/28/target_20211128143333.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/29/target_20211129001901.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/30/target_20211130142913.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/11/30/target_20211130192406.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/06/target_20211206122629.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/06/target_20211206202921.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/08/target_20211208090556.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/09/target_20211209125750.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/12/target_20211212115433.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/13/target_20211213173628.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/13/target_20211213191245.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/14/target_20211214101434.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/15/target_20211215155105.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/19/target_20211219055608.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/21/target_20211221071315.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/21/target_20211221071621.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/22/target_20211222075716.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/23/target_20211223150935.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/24/target_20211224043626.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/24/target_20211224075111.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/26/target_20211226141252.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/28/target_20211228041626.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/29/target_20211229033040.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/29/target_20211229045917.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/xs/on_swath/2021/12/29/target_20211229130644.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/05/target_20180105075447.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/05/target_20180105075659.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/05/target_20180105195418.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/05/target_20180105213044.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/07/target_20180107043807.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/07/target_20180107062018.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/08/target_20180108065259.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/09/target_20180109060209.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/09/target_20180109193414.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/09/target_20180109210846.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/10/target_20180110201938.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/11/target_20180111192835.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/12/target_20180112033547.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/12/target_20180112050645.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/12/target_20180112050847.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/12/target_20180112214427.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/13/target_20180113041016.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/13/target_20180113041709.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/13/target_20180113055146.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/13/target_20180113174419.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/14/target_20180114032540.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/14/target_20180114045410.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/14/target_20180114165237.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/15/target_20180115040304.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/15/target_20180115040620.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/15/target_20180115040952.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/16/target_20180116030903.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/16/target_20180116031035.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/16/target_20180116181926.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/16/target_20180116212713.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/17/target_20180117035604.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/17/target_20180117235548.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/18/target_20180118043541.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/19/target_20180119020817.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/19/target_20180119154101.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/20/target_20180120012220.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/20/target_20180120025528.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/20/target_20180120025745.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/21/target_20180121003206.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/21/target_20180121015938.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/21/target_20180121020849.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/21/target_20180121153139.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/21/target_20180121170533.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/22/target_20180122143629.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/22/target_20180122161102.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/23/target_20180123015407.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/23/target_20180123152549.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/24/target_20180124142814.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/24/target_20180124143106.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/24/target_20180124173552.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/25/target_20180125133851.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/25/target_20180125164454.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/25/target_20180125232047.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/26/target_20180126005406.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/26/target_20180126005438.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/26/target_20180126172852.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/27/target_20180127133415.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/27/target_20180127213510.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/27/target_20180127231221.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/28/target_20180128021831.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/28/target_20180128235211.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/28/target_20180128235313.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/30/target_20180130123348.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/30/target_20180130203509.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/31/target_20180131131446.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/31/target_20180131144548.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/01/31/target_20180131225601.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/05/target_20180205133615.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/05/target_20180205200410.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/06/target_20180206124201.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/06/target_20180206155305.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/06/target_20180206191420.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/06/target_20180206205124.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/08/target_20180208110250.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/08/target_20180208140924.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/08/target_20180208204143.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/09/target_20180209100433.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/10/target_20180210091205.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/10/target_20180210104906.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/10/target_20180210122645.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/10/target_20180210172041.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/11/target_20180211112757.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/11/target_20180211193213.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/12/target_20180212184834.nc'),
#   PosixPath('/home/simon/data/ipwgml_spr_gmi/spr/gmi/training/s/on_swath/2018/02/12/target_20180212201942.nc'),
#   ...]}

# %% [markdown]
# With these settings, we can instantiate the training data dataset. By setting ``stack=True`` we also tell the retrieval to stack all input tensors instead of loading the input data as a dictionary.
#
# > **Note**: The current implementation of the dataset loads all training data into memory upon instantiation. Therefore, executing the cell below may take some time.

# %%
from torch.utils.data import DataLoader
from ipwgml.pytorch.datasets import SPRTabular

training_data = SPRTabular(
    reference_sensor="gmi",
    geometry=geometry,
    split="training",
    subset="s",
    retrieval_input=inputs,
    batch_size=batch_size,
    target_config=target_config,
    stack=True,
    download=True,
)
training_loader = DataLoader(training_data, shuffle=True, batch_size=None, num_workers=4)
# Out:
# <xarray.Dataset> Size: 8MB
# Dimensions:       (samples: 63558, time: 16, latitude: 256, longitude: 256)
# Coordinates:
#   * latitude      (latitude) float64 2kB 41.74 41.71 41.67 ... 32.54 32.5 32.47
#   * longitude     (longitude) float64 2kB -94.89 -94.86 -94.82 ... -85.65 -85.62
# Dimensions without coordinates: samples, time
# Data variables:
#     observations  (samples, time) float64 8MB 275.0 275.0 276.0 ... 246.0 253.0

# %% [markdown]
# With the above configuration, the training data loaded by the ``training_loader`` has the following dimensions.

# %%
inpt, target = next(iter(training_loader))
print("Input tensor shape: ", inpt.shape)
print("Target tensor shape: ", target.shape)
# Out:
# Input tensor shape:  torch.Size([1024, 16])
# Target tensor shape:  torch.Size([1024])

# %%
y = inpt[:, -1]
x = target

# %% [markdown]
# We also create a validation loader with the same configuration.

# %%
validation_data = SPRTabular(
    reference_sensor="gmi",
    geometry="on_swath",
    split="validation",
    subset="s",
    retrieval_input=inputs,
    batch_size=batch_size,
    target_config=target_config,
    stack=True,
    download=True,
    shuffle=False
)
validation_loader = DataLoader(validation_data, shuffle=True, batch_size=None)
# Out:
# <xarray.Dataset> Size: 104kB
# Dimensions:       (samples: 804, time: 16, scan: 64, pixel: 64)
# Coordinates:
#   * scan          (scan) int64 512B 0 1 2 3 4 5 6 7 ... 56 57 58 59 60 61 62 63
#   * pixel         (pixel) int64 512B 0 1 2 3 4 5 6 7 ... 56 57 58 59 60 61 62 63
# Dimensions without coordinates: samples, time
# Data variables:
#     observations  (samples, time) float64 103kB nan 258.0 257.0 ... 274.0 274.0

# %%
from typing import Any, Callable, Dict

import torch
from torch import optim
from torch import nn
from torch.nn.functional import binary_cross_entropy_with_logits
import lightning as L

OUTPUTS = [
    "surface_precip",
    "probability_of_precip",
    "probability_of_heavy_precip"
]

N_EPOCHS = 20

class MLP(L.LightningModule):
    """
    Lightning module implementing a multi-layer perceptron (MLP) for retrieving precipitation from satellite
    observations.
    """
    def __init__(
        self,
        n_input_features: int,
        n_hidden_layers: int,
        n_neurons: int,
        activation_fn: Callable[[], nn.Module] = nn.GELU,
        normalization_layer: Callable[[int], nn.Module] = nn.LayerNorm,
        n_epochs: int = N_EPOCHS
    ):
        """
        Args:
            n_input_features: The number of features in the input
            n_hidden_layers: The number of hidden layers in the MLP
            n_neurons: The number of neurons in the hidden layers
            activation_fn: A callable to create activation function layers.
            normalization_layer: A callable to create normalization layers.
            n_epochs: The numebr of epochs the model will be trained for.
        """
        super().__init__()
        blocks = [
            nn.Linear(n_input_features, n_neurons),
            normalization_layer(n_neurons),
            activation_fn(),
        ]
        for _ in range(n_hidden_layers):
            blocks += [
                nn.Linear(n_neurons, n_neurons),
                normalization_layer(n_neurons),
                activation_fn(),
            ]
        self.body = nn.Sequential(*blocks)

        heads = {}
        for output in OUTPUTS:
            heads[output] =  nn.Sequential(
                nn.Linear(n_neurons, n_neurons),
                normalization_layer(n_neurons),
                activation_fn(),
                nn.Linear(n_neurons, 1)
            )
        self.heads = nn.ModuleDict(heads)
        self.n_epochs = N_EPOCHS

    def forward(self, retrieval_input: torch.Tensor) -> Dict[str, torch.Tensor]:
        """
        Forward retrieval input through network and produce dictionary with predictions.

        Args:
            retrieval_input: The retrieval input as a single torch.Tensor.

        Return:
            A dictionary containing the predictions for 'surface_precip', 'probability_of_precip',
            and 'probability_of_heavy_precip'.
        """
        y = self.body(retrieval_input)
        return {
            name: module(y) for name, module in self.heads.items()
        }
        
    def training_step(self, batch, batch_idx) -> torch.Tensor:
        """
        Calculates the loss-function gradients for the MLP.

        The loss is calculated as the sum of the MSE for 'surface_precip' and the binary cross-entropy loss
        for precipitation detection and heavy precipitation detection.

        Args:
            batch: A tuple containing the training data loaded from the data loader.
            batch_idx: The index of the batch in the current epoch. Not used.

        Return:
            A scalar torch.Tensor containing the total loss.
        """
        inpt, surface_precip = batch
        pred = self(inpt)

        valid = torch.isfinite(surface_precip)
        surface_precip = surface_precip[valid]
        precip_mask = (surface_precip > 1e-3).to(dtype=torch.float32)
        heavy_precip_mask = (surface_precip > 10).to(dtype=torch.float32)
        surface_precip_pred = pred["surface_precip"][valid]
        pop = pred["probability_of_precip"][valid]
        pohp = pred["probability_of_heavy_precip"][valid]
        
        # MSE loss for QPE
        loss_estim = ((surface_precip_pred[..., 0] - surface_precip) ** 2).mean()
        # BCE loss for detection targets
        loss_detect = binary_cross_entropy_with_logits(pop[..., 0], precip_mask)
        loss_detect_heavy = binary_cross_entropy_with_logits(pohp[..., 0], heavy_precip_mask)
        tot_loss =  loss_estim + loss_detect + loss_detect_heavy
        return tot_loss

    def validation_step(self, batch, batch_idx) -> None:
        """
        Calculates the loss-function values on validation data.

        Args:
            batch: A tuple containing the training data loaded from the data loader.
            batch_idx: The index of the batch in the current epoch. Not used.
        """
        inpt, surface_precip = batch
        pred = self(inpt)

        valid = torch.isfinite(surface_precip)
        surface_precip = surface_precip[valid]
        precip_mask = (surface_precip > 1e-3).to(dtype=torch.float32)
        heavy_precip_mask = (surface_precip > 10).to(dtype=torch.float32)
        surface_precip_pred = pred["surface_precip"][valid]
        pop = pred["probability_of_precip"][valid]
        pohp = pred["probability_of_heavy_precip"][valid]
        
        # MSE loss for QPE
        loss_estim = ((surface_precip_pred[..., 0] - surface_precip) ** 2).mean()
        # BCE loss for detection targets
        loss_detect = binary_cross_entropy_with_logits(pop[..., 0], precip_mask)
        loss_detect_heavy = binary_cross_entropy_with_logits(pohp[..., 0], heavy_precip_mask)
        tot_loss =  loss_estim + loss_detect + loss_detect_heavy

        opt = self.optimizers()
        learning_rate = opt.param_groups[0]['lr']
        
        self.log_dict(
            {
                "val_loss": loss_estim + loss_detect + loss_detect_heavy,
                "val_loss_estim": loss_estim,
                "val_loss_detect": loss_detect,
                "val_loss_detect_heavy": loss_detect_heavy,
                "learning_rate": learning_rate
            },
            on_epoch=True,
            prog_bar=True
        )
    
    def configure_optimizers(self) -> Dict[str, Any]:
        """
        We use the Adam optimizer with a cosine annealing learning rate schedule.
        """
        optimizer = optim.Adam(self.parameters(), lr=5e-4)
        scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=self.n_epochs)
        return {
            "optimizer": optimizer,
            "lr_scheduler": scheduler
        }

# %%
mlp = MLP(n_input_features=16, n_hidden_layers=8, n_neurons=256)

# %%
trainer = L.Trainer(max_epochs=N_EPOCHS)
trainer.fit(model=mlp, train_dataloaders=training_loader, val_dataloaders=validation_loader)
# Out:
# INFO: Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# [05/23/25 23:08:18] INFO     INFO:lightning.pytorch.utilities.rank_zero:Trainer will use only 1 of  ]8;id=301252;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py\rank_zero.py]8;;\:]8;id=95782;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py#63\63]8;;\
#                              2 GPUs because it is running inside an interactive / notebook
#                              environment. You may try to set `Trainer(devices=2)` but please note
#                              that multi-GPU inside interactive / notebook environments is
#                              considered experimental and unstable. Your mileage may vary.
# INFO: GPU available: True (cuda), used: True
#                     INFO     INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), ]8;id=919734;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py\rank_zero.py]8;;\:]8;id=42236;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py#63\63]8;;\
#                              used: True
# INFO: TPU available: False, using: 0 TPU cores
#                     INFO     INFO:lightning.pytorch.utilities.rank_zero:TPU available: False,       ]8;id=305903;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py\rank_zero.py]8;;\:]8;id=178907;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py#63\63]8;;\
#                              using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
#                     INFO     INFO:lightning.pytorch.utilities.rank_zero:HPU available: False,       ]8;id=110501;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py\rank_zero.py]8;;\:]8;id=240671;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py#63\63]8;;\
#                              using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#                     INFO     INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 -                    ]8;id=275865;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning/pytorch/accelerators/cuda.py\cuda.py]8;;\:]8;id=446117;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning/pytorch/accelerators/cuda.py#61\61]8;;\
#                              CUDA_VISIBLE_DEVICES: [0,1]
# INFO:
#   | Name  | Type       | Params | Mode
# ---------------------------------------------
# 0 | body  | Sequential | 535 K  | train
# 1 | heads | ModuleDict | 199 K  | train
# ---------------------------------------------
# 734 K     Trainable params
# 0         Non-trainable params
# 734 K     Total params
# 2.940     Total estimated model params size (MB)
# 44        Modules in train mode
# 0         Modules in eval mode
#                     INFO     INFO:lightning.pytorch.callbacks.model_summary:                   ]8;id=639397;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_summary.py\model_summary.py]8;;\:]8;id=290849;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_summary.py#104\104]8;;\
#                                | Name  | Type       | Params | Mode
#                              ---------------------------------------------
#                              0 | body  | Sequential | 535 K  | train
#                              1 | heads | ModuleDict | 199 K  | train
#                              ---------------------------------------------
#                              734 K     Trainable params
#                              0         Non-trainable params
#                              734 K     Total params
#                              2.940     Total estimated model params size (MB)
#                              44        Modules in train mode
#                              0         Modules in eval mode
# Sanity Checking: |                                                                                            …
# /home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:476: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# /home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# Training: |                                                                                                   …
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Validation: |                                                                                                 …
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Validation: |                                                                                                 …
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Validation: |                                                                                                 …
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# INFO: `Trainer.fit` stopped: `max_epochs=20` reached.
# [05/24/25 00:58:23] INFO     INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped:      ]8;id=566290;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py\rank_zero.py]8;;\:]8;id=413725;file:///home/simon/miniforge3/envs/ipwgml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py#63\63]8;;\
#                              `max_epochs=20` reached.

# %% [markdown]
# # Evaluating the retrieval
#
# In oder to compare the MLP-based precipitation retrieval to conventional precipitation retrievals, we can use the ``ipwgml.evaluation.Evaluator`` to evaluate the retrieval on the exact same overpasses that we used to evaluate [the IMERG](evaluate_imerg.ipynb) and [GPROF](evaluate_gprof.ipynb) retrievals. To ensure consistency between training and evaluation data, we instantiate the evaluator with the same values for ``geometry`` and ``retrieval_input``.

# %%
from ipwgml.evaluation import Evaluator
evaluator = Evaluator(
    reference_sensor="gmi",
    geometry=geometry,
    retrieval_input=inputs,
    domain="conus",
    download=True
)

# %% [markdown]
# ## The retrieval callback function
#
# Evaluating the MLP using the ``ipwgml.evaluation.Evaluator`` requires implementing a retrieval callback function that the evaluator can call to obtain the rerieval results for a given collocation scene. The ``Evaluator`` class supports loading the retrieval input data in tabular format. Therefore, all that has to be done ine retrieval callback function is extracting the required input data and feeding it into the MLP.

# %%
from ipwgml.pytorch import PytorchRetrieval
mlp_retrieval = PytorchRetrieval(mlp, retrieval_input=inputs, stack=True, device=torch.device("cpu"))

# %% [markdown]
# ## Case study

# %%
fig = evaluator.plot_retrieval_results(0, mlp_retrieval, input_data_format="tabular", batch_size=1024)
# Out:
# /home/simon/data/ipwgml_spr_gmi/spr/gmi/evaluation/conus/gridded/2022/01/01/geo_ir_20220101022714.nc

# %%
fig = evaluator.plot_retrieval_results(0, mlp_retrieval, input_data_format="tabular", batch_size=1024)
# Out:
# /home/simon/data/ipwgml_spr_gmi/spr/gmi/evaluation/conus/on_swath/2022/01/01/geo_ir_20220101022714.nc

# %%
fig = evaluator.plot_retrieval_results(49, mlp_retrieval, input_data_format="tabular", batch_size=1024)

# %% [markdown]
# ## Evaluation

# %%
evaluator.evaluate(retrieval_fn=mlp_retrieval, input_data_format="tabular", batch_size=4048, n_processes=1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## Results

# %% [markdown]
# ### Precipitation quantification

# %%
evaluator.get_precip_quantification_results(name="MLP (GMI)").T
# Out:
#                                  MLP (GMI)  IMERG Final V7 (GMI)  \
# Bias [$\%$]                      -8.161608             -7.398772
# MAE [$mm h^{-1}$]                 0.101430              0.124924
# MSE [$(mm h^{-1})^2$]             0.843856              1.731411
# SMAPE$_{0.1}$ [$\%$]             84.773240            114.417614
# Correlation coeff. []             0.661201              0.455411
# Effective resolution [$^\circ$]        inf                   inf
#
#                                  GPROF V7 (GMI)
# Bias [$\%$]                            5.799770
# MAE [$mm h^{-1}$]                      0.119785
# MSE [$(mm h^{-1})^2$]                  1.413339
# SMAPE$_{0.1}$ [$\%$]                  91.327371
# Correlation coeff. []                  0.552348
# Effective resolution [$^\circ$]        0.423000

# %%
res = evaluator.precip_quantification_metrics[-1].compute()

# %%
res.spectral_coherence
# Out:
# <xarray.DataArray 'spectral_coherence' (scales: 24)> Size: 192B
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])
# Coordinates:
#   * scales   (scales) float64 192B inf 0.846 0.423 ... 0.04029 0.03845 0.03678
# Attributes:
#     full_name:  Spectral coherence
#     unit:

# %%
sc = evaluator.precip_quantification_metrics[-1].compute()
# Out:
# /home/simon/src/ipwgml/src/ipwgml/metrics.py:665: RuntimeWarning: divide by zero encountered in divide
#   scales = 0.5 * (N - 1) * self.scale / n

# %% [markdown]
# ### Precipitation detection

# %%
evaluator.get_precip_detection_results(name="MLP (GMI)").T
# Out:
#         MLP (GMI)  IMERG Final V7 (GMI)  GPROF V7 (GMI)
# POD []   0.677825              0.687576        0.758366
# FAR []   0.239219              0.497714        0.462010
# HSS []   0.750935              0.470956        0.508161

# %% [markdown]
# ### Probabilistic precipitation detection

# %%
evaluator.get_prob_precip_detection_results(name="MLP (GMI)").T
# Out:
# /home/simon/src/ipwgml/src/ipwgml/metrics.py:904: RuntimeWarning: invalid value encountered in divide
#   precision = self.n_tp / (self.n_tp + self.n_fp)
#         MLP (GMI)  IMERG Final V7 (GMI)  GPROF V7 (GMI)
# AUC []   0.763957                   0.0         0.54994

# %% [markdown]
# ### Heavy precipitation detection

# %%
evaluator.get_heavy_precip_detection_results(name="MLP (GMI)").T
# Out:
#         MLP (GMI)  IMERG Final V7 (GMI)  GPROF V7 (GMI)
# POD []   0.354196              0.687576        0.758366
# FAR []   0.381846              0.497714        0.462010
# HSS []   0.617587              0.470956        0.508161

# %% [markdown]
# ### Heavy probabilistic precipitation detection

# %%
evaluator.get_prob_heavy_precip_detection_results(name="MLP (GMI)").T
# Out:
# /home/simon/src/ipwgml/src/ipwgml/metrics.py:904: RuntimeWarning: invalid value encountered in divide
#   precision = self.n_tp / (self.n_tp + self.n_fp)
#         MLP (GMI)  IMERG Final V7 (GMI)  GPROF V7 (GMI)
# AUC []   0.488586                   0.0        0.298044
