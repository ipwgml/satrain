# %% [markdown]
# # Baselines
#
# This page summarizes baseline results for a range of existing satellite-based precipitation products evaluated using the SatRain benchmark dataset. The results are intended to provide a common point of reference for the development and evaluation of new precipitation retrieval algorithms.
#
# | Product | Primary Reference | Implementation | Evaluation Notebook |
# |---|---|---|---|
# | GPROF V07 | [https://doi.org/10.1007/978-3-030-24568-9_8](https://doi.org/10.1007/978-3-030-24568-9_8) |   | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/gprof_v07.ipynb) |
# | GPROF V08 | Upcoming | [github.com/simonpf/gprof_nn](https://github.com/simonpf/gprof_nn)   | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/gprof_v08.ipynb) |
# | ERA5 | [https://doi.org/10.1002/qj.3803](https://doi.org/10.1002/qj.3803) |  | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/era5.ipynb) |
# | PERSIANN CCS | https://doi.org/10.1175/JAM2173.1  |  |[Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/persiann_ccs.ipynb) |
# | PERSIANN PDIR-Now | https://doi.org/10.1175/JHM-D-20-0177.1 |  | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/persiann_pdir_now.ipynb) |
# | PU-Net | [https://doi.org/10.1175/JHM-D-25-0162.1](https://doi.org/10.1175/JHM-D-25-0162.1) |  | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/punet.ipynb) |
# | GPROF-IR | [https://doi.org/10.48550/arXiv.2605.07167](https://doi.org/10.48550/arXiv.2605.07167) | [github.com/simonpf/gprof_ir](https://github.com/simonpf/gprof_ir) | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/gprof_ir.ipynb) |
#
# The results below are reported separately for the GMI- and ATMS-based subsets of SatRain.

# %% [markdown]
# ## Base Sensor: GMI

# %% [markdown]
# ### Quantitaive Precipitation Estimation

# %%
import xarray as xr
res_gprof_ir = xr.load_dataset("/home/simon/src/satrain/src/satrain/files/baselines/gprof_ir_gmi_austria.nc")
res_punet = xr.load_dataset("/home/simon/src/satrain/src/satrain/files/baselines/punet_gmi_austria.nc")
res_gprof = xr.load_dataset("/home/simon/src/satrain/src/satrain/files/baselines/gprof_v08_gmi_austria.nc")

# %%
from IPython.display import HTML, display
from satrain.baselines import get_ranked_results, plot_baselines_interactive, QPE_METRICS
results = get_ranked_results(base_sensor="gmi", metrics=list(QPE_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div style="height:400px; width:1200px;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="9e2c63c8-d378-43e5-a2e6-75fd5655ef09" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9e2c63c8-d378-43e5-a2e6-75fd5655ef09")) {                    Plotly.newPlot(                        "9e2c63c8-d378-43e5-a2e6-75fd5655ef09",                        [{"alignmentgroup":"True","customdata":[["bias","GPROF V08 (GMI)","PMW"],["bias","GPROF V08 (GMI)","PMW"],["bias","GPROF V08 (GMI)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V08 (GMI)","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF V08 (GMI)","offsetgroup":"GPROF V08 (GMI)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"DN0Ux8ucRkCdBGVC8lwIwLIp+DxoqCvA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","GPROF-IR","IR"],["bias","GPROF-IR","IR"],["bias","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#e67660","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"2FbYK0Y4S0AukuLVzEMcQIQAEHPiqzPA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","GPROF V07 (GMI)","PMW"],["bias","GPROF V07 (GMI)","PMW"],["bias","GPROF V07 (GMI)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (GMI)","marker":{"color":"#db565d","pattern":{"shape":""}},"name":"GPROF V07 (GMI)","offsetgroup":"GPROF V07 (GMI)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AxZrBHtKVUA23ZOC55Pzv24OPcssky\u002fA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","ERA5","Reanalysis"],["bias","ERA5","Reanalysis"],["bias","ERA5","Reanalysis"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ERA5","marker":{"color":"#c14168","pattern":{"shape":""}},"name":"ERA5","offsetgroup":"ERA5","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"pzn7x9\u002fWLkAUuApeRTP9v2yTQfzfMCnA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PU-Net","IR"],["bias","PU-Net","IR"],["bias","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#a1386f","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"OnW4KzJOBcARXV7\u002fi5UqQAeTLCug5hvA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PERSIANN PDIR-Now","IR"],["bias","PERSIANN PDIR-Now","IR"],["bias","PERSIANN PDIR-Now","IR"]],"hovert ...

# %% [markdown]
# ### Precipitation Detection
#
# The precipitation-detection skill of all retrievals is assessed based on their ability to identify reference precipitation rates exceeding 0.1 mm h$^{-1}$. For algorithms that provide a precipitation mask or flag, this information is used to compute the probability of detection (POD), false alarm rate (FAR), and Heidke Skill Score (HSS). If an algorithm additionally provides probabilistic precipitation estimates, detection performance is further evaluated using the area under the Precision–Recall (PR) curve. For algorithms that do not provide dedicated precipitation-detection outputs, all pixels with retrieved precipitation rates exceeding 0.1 mm h$^{-1}$ are classified as raining and evaluated using POD, FAR, and HSS. Because the area under the PR curve requires probabilistic detection output, this metric cannot be computed for products that do not provide precipitation probabilities.

# %%
from satrain.baselines import DETECTION_METRICS


results = get_ranked_results(base_sensor="gmi", metrics=list(DETECTION_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div style="height:400px; width:1200px;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="a1d39f7a-5062-4d5d-ab03-a5d83964d76f" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a1d39f7a-5062-4d5d-ab03-a5d83964d76f")) {                    Plotly.newPlot(                        "a1d39f7a-5062-4d5d-ab03-a5d83964d76f",                        [{"alignmentgroup":"True","customdata":[["pod","GPROF-IR","IR"],["pod","GPROF-IR","IR"],["pod","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"iJsn35Fh4z9jjyKMTOLlP7zYjkVsDOU\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PU-Net","IR"],["pod","PU-Net","IR"],["pod","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#e67660","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"DIJ8Dfh23j+o9E\u002fgIwDiP2gtGbbjTOQ\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","ERA5","Reanalysis"],["pod","ERA5","Reanalysis"],["pod","ERA5","Reanalysis"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ERA5","marker":{"color":"#db565d","pattern":{"shape":""}},"name":"ERA5","offsetgroup":"ERA5","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"jC666KKL5D92iIHizrvpP8uL9wUXj+g\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","GPROF V07 (GMI)","PMW"],["pod","GPROF V07 (GMI)","PMW"],["pod","GPROF V07 (GMI)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (GMI)","marker":{"color":"#c14168","pattern":{"shape":""}},"name":"GPROF V07 (GMI)","offsetgroup":"GPROF V07 (GMI)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"\u002fRlfbASI5j+j6mossTbnP+fMgOSytOg\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PERSIANN CCS","IR"],["pod","PERSIANN CCS","IR"],["pod","PERSIANN CCS","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN CCS","marker":{"color":"#a1386f","pattern":{"shape":""}},"name":"PERSIANN CCS","offsetgroup":"PERSIANN CCS","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"JjftAUijxj9lpfwDQJjQP7QrR8\u002foJNA\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PERSIANN PDIR-Now","IR"],["pod","PERSIANN PDIR-Now","IR"],["pod","PERSIANN PDIR-Now","IR"]],"hovertemplate":"algo ...

# %% [markdown]
# ### Heavy Precipitation Detection
#
# The heavy-precipitation-detection skill of all retrievals is evaluated by testing their ability to identify reference precipitation rates exceeding 10 mm h$^{-1}$. The metrics are the same as for the detection of precipitation.

# %%
from satrain.baselines import HEAVY_DETECTION_METRICS
results = get_ranked_results(base_sensor="gmi", metrics=list(HEAVY_DETECTION_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div style="height:400px; width:1200px;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="c569362c-ea27-444c-b052-8ec9b5c799b5" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c569362c-ea27-444c-b052-8ec9b5c799b5")) {                    Plotly.newPlot(                        "c569362c-ea27-444c-b052-8ec9b5c799b5",                        [{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF V08 (GMI)","PMW"],["pod_heavy","GPROF V08 (GMI)","PMW"],["pod_heavy","GPROF V08 (GMI)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V08 (GMI)","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF V08 (GMI)","offsetgroup":"GPROF V08 (GMI)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA0D\u002fiIRDPj\u002frUP6oBspyVf9M\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF V07 (GMI)","PMW"],["pod_heavy","GPROF V07 (GMI)","PMW"],["pod_heavy","GPROF V07 (GMI)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (GMI)","marker":{"color":"#e67660","pattern":{"shape":""}},"name":"GPROF V07 (GMI)","offsetgroup":"GPROF V07 (GMI)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA0D+GfMALoSjIP2cluDxepdA\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF-IR","IR"],["pod_heavy","GPROF-IR","IR"],["pod_heavy","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#db565d","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAALrVsjg+2+P9LVbw\u002fZJrI\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","PU-Net","IR"],["pod_heavy","PU-Net","IR"],["pod_heavy","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#c14168","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAACOCTzeBYTDPzoCymfweck\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","PERSIANN PDIR-Now","IR"],["pod_heavy","PERSIANN PDIR-Now","IR"],["pod_heavy","PERSIANN PDIR-Now","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN PDIR-Now","marker":{"color":"#a1386f","pattern":{"shape":""}},"name":"PERSIANN PDIR-Now","offsetgroup":"PERSIANN PDIR-Now","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAAJKfSqECK0P8rSZXo8N7c\u002f"},"yaxis":"y","type":"b ...

# %% [markdown]
# ## Base Sensor: ATMS
#
# ### Quantitative Precipitation Estimation

# %%
from satrain.baselines import get_ranked_results, plot_baselines_interactive, QPE_METRICS

results = get_ranked_results(base_sensor="atms", metrics=list(QPE_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div style="height:400px; width:1200px;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="f8948fe7-62ed-47f1-a777-61ef3de53e20" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f8948fe7-62ed-47f1-a777-61ef3de53e20")) {                    Plotly.newPlot(                        "f8948fe7-62ed-47f1-a777-61ef3de53e20",                        [{"alignmentgroup":"True","customdata":[["bias","GPROF V08 (ATMS)","PMW"],["bias","GPROF V08 (ATMS)","PMW"],["bias","GPROF V08 (ATMS)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V08 (ATMS)","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF V08 (ATMS)","offsetgroup":"GPROF V08 (ATMS)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"Y9lawMVOW0AQrmFz8tjGv5VVnsjjfBnA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","GPROF-IR","IR"],["bias","GPROF-IR","IR"],["bias","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#e67660","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"ukdSc0n+VkDLuooZwHgbQAMlND5AFinA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","GPROF V07 (ATMS)","PMW"],["bias","GPROF V07 (ATMS)","PMW"],["bias","GPROF V07 (ATMS)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (ATMS)","marker":{"color":"#db565d","pattern":{"shape":""}},"name":"GPROF V07 (ATMS)","offsetgroup":"GPROF V07 (ATMS)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"ej6HerczYUCP47ye4Gv5v+lrt6ES0AvA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","ERA5","Reanalysis"],["bias","ERA5","Reanalysis"],["bias","ERA5","Reanalysis"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ERA5","marker":{"color":"#c14168","pattern":{"shape":""}},"name":"ERA5","offsetgroup":"ERA5","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"eCPzVppQVECvZQxIIin3Py2IVLfQEh7A"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PU-Net","IR"],["bias","PU-Net","IR"],["bias","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#a1386f","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"OzvUBbzqTkCsyrDH+pAgQAr7nIhkf\u002fk\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PERSIANN PDIR-Now","IR"],["bias","PERSIANN PDIR-Now","IR"],["bias","PERSIANN PDIR-Now","IR"]], ...

# %% [markdown]
# ### Precipitation Detection

# %%
from satrain.baselines import DETECTION_METRICS

results = get_ranked_results(base_sensor="atms", metrics=list(DETECTION_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div style="height:400px; width:1200px;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="c77a0cdd-d6c5-4452-8cb2-5fd9d6b205d7" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c77a0cdd-d6c5-4452-8cb2-5fd9d6b205d7")) {                    Plotly.newPlot(                        "c77a0cdd-d6c5-4452-8cb2-5fd9d6b205d7",                        [{"alignmentgroup":"True","customdata":[["pod","GPROF V08 (ATMS)","PMW"],["pod","GPROF V08 (ATMS)","PMW"],["pod","GPROF V08 (ATMS)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V08 (ATMS)","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF V08 (ATMS)","offsetgroup":"GPROF V08 (ATMS)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"J1T3o0Bo5T9d+\u002f6CcirnP7fOBUPcXeY\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","GPROF-IR","IR"],["pod","GPROF-IR","IR"],["pod","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#e67660","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"ba0w89rT3z8zRPbuO0HmP8RK5axzm+U\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PU-Net","IR"],["pod","PU-Net","IR"],["pod","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#db565d","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"wCuWov1D3T+4WPbuuR3iP+KsVpOzwOM\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","ERA5","Reanalysis"],["pod","ERA5","Reanalysis"],["pod","ERA5","Reanalysis"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ERA5","marker":{"color":"#c14168","pattern":{"shape":""}},"name":"ERA5","offsetgroup":"ERA5","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"eQZwg9NdyD+xByrIVTjqP1zsR4C0lug\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","GPROF V07 (ATMS)","PMW"],["pod","GPROF V07 (ATMS)","PMW"],["pod","GPROF V07 (ATMS)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (ATMS)","marker":{"color":"#a1386f","pattern":{"shape":""}},"name":"GPROF V07 (ATMS)","offsetgroup":"GPROF V07 (ATMS)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"9qGxPjTW5z\u002fSi0BvF+znP\u002fMDfLo88Og\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PERSIANN CCS","IR"],["pod","PERSIANN CCS","IR"],["pod","PERSIANN CCS","IR"]],"ho ...

# %% [markdown]
# ### Heavy Precipitation Detection

# %%
from satrain.baselines import HEAVY_DETECTION_METRICS

results = get_ranked_results(base_sensor="atms", metrics=list(HEAVY_DETECTION_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div style="height:400px; width:1200px;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="64ad4304-dd7f-443e-88cd-bdf7fe46fd7d" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("64ad4304-dd7f-443e-88cd-bdf7fe46fd7d")) {                    Plotly.newPlot(                        "64ad4304-dd7f-443e-88cd-bdf7fe46fd7d",                        [{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF V08 (ATMS)","PMW"],["pod_heavy","GPROF V08 (ATMS)","PMW"],["pod_heavy","GPROF V08 (ATMS)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V08 (ATMS)","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF V08 (ATMS)","offsetgroup":"GPROF V08 (ATMS)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAAXghdFOszFP+AfGdvph8Y\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF-IR","IR"],["pod_heavy","GPROF-IR","IR"],["pod_heavy","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#e67660","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAAnqJ8Vv0K5PyGidEvFqLE\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","PU-Net","IR"],["pod_heavy","PU-Net","IR"],["pod_heavy","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#db565d","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAABvuZvGjYPBP9QnFoT3W8U\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF V07 (ATMS)","PMW"],["pod_heavy","GPROF V07 (ATMS)","PMW"],["pod_heavy","GPROF V07 (ATMS)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (ATMS)","marker":{"color":"#c14168","pattern":{"shape":""}},"name":"GPROF V07 (ATMS)","offsetgroup":"GPROF V07 (ATMS)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAABVMIWqnPi5PxiLRvdgKb4\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","PERSIANN PDIR-Now","IR"],["pod_heavy","PERSIANN PDIR-Now","IR"],["pod_heavy","PERSIANN PDIR-Now","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN PDIR-Now","marker":{"color":"#a1386f","pattern":{"shape":""}},"name":"PERSIANN PDIR-Now","offsetgroup":"PERSIANN PDIR-Now","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAAt7MxVnvOzP4n5HT9pYLc\u002f"},"yaxis":"y","type":"bar" ...
