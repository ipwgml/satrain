# %% [markdown]
# # Baselines
#
# This page summarizes baseline results for a range of existing satellite-based precipitation products evaluated using the SatRain benchmark dataset. The results are intended to provide a common point of reference for the development and evaluation of new precipitation retrieval algorithms.
#
# | Product | Primary Reference | Implementation | Evaluation Notebook |
# |---|---|---|---|
# | GPROF V07 | [https://doi.org/10.1007/978-3-030-24568-9_8](https://doi.org/10.1007/978-3-030-24568-9_8) |   | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/gprof_v07.ipynb) |
# | ERA5 | [https://doi.org/10.1002/qj.3803](https://doi.org/10.1002/qj.3803) |  | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/era5.ipynb) |
# | PERSIANN CCS | https://doi.org/10.1175/JAM2173.1  |  |[Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/persiann_ccs.ipynb) |
# | PERSIANN PDIR-Now | https://doi.org/10.1175/JHM-D-20-0177.1 |  | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/persiann_pdir_now.ipynb) |
# | PU-Net | [https://doi.org/10.1175/JHM-D-25-0162.1](https://doi.org/10.1175/JHM-D-25-0162.1) |  | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/punet.ipynb) |
# | GPROF-IR | [https://doi.org/10.48550/arXiv.2605.07167](https://doi.org/10.48550/arXiv.2605.07167) | [github.com/simonpf/gprof_ir](https://github.com/simonpf/gprof_ir) | [Notebook](https://github.com/ipwgml/satrain/blob/main/notebooks/baselines/gprof_ir.ipynb) |
#
# The results below are reported separately for the GMI- and ATMS-based subsets of SatRain.

# %% [markdown]
# ## Base Sensor: GMI

# %% [markdown]
# ### Quantitaive Precipitation Estimation

# %%
from IPython.display import HTML, display
from satrain.baselines import get_ranked_results, plot_baselines_interactive, QPE_METRICS

results = get_ranked_results(base_sensor="gmi", metrics=list(QPE_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="2a697fb6-ecc1-4cdb-a1ee-dbe96c8df3bc" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2a697fb6-ecc1-4cdb-a1ee-dbe96c8df3bc")) {                    Plotly.newPlot(                        "2a697fb6-ecc1-4cdb-a1ee-dbe96c8df3bc",                        [{"alignmentgroup":"True","customdata":[["bias","GPROF-IR","IR"],["bias","GPROF-IR","IR"],["bias","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"5BNJKF1kT0AjEkghydEdQA4BypLr\u002fDPA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","ERA5","Reanalysis"],["bias","ERA5","Reanalysis"],["bias","ERA5","Reanalysis"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ERA5","marker":{"color":"#e46f5e","pattern":{"shape":""}},"name":"ERA5","offsetgroup":"ERA5","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"WAXMA4dSU0AUuApeRTP9vxMTX\u002fiCLinA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PU-Net","IR"],["bias","PU-Net","IR"],["bias","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#d24b60","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"hGynHp\u002feQEARXV7\u002fi5UqQAeTLCug5hvA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","GPROF V07 (GMI)","PMW"],["bias","GPROF V07 (GMI)","PMW"],["bias","GPROF V07 (GMI)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (GMI)","marker":{"color":"#af3b6d","pattern":{"shape":""}},"name":"GPROF V07 (GMI)","offsetgroup":"GPROF V07 (GMI)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"NARnVXzPY0A23ZOC55Pzv24OPcssky\u002fA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PERSIANN PDIR-Now","IR"],["bias","PERSIANN PDIR-Now","IR"],["bias","PERSIANN PDIR-Now","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN PDIR-Now","marker":{"color":"#883171","pattern":{"shape":""}},"name":"PERSIANN PDIR-Now","offsetgroup":"PERSIANN PDIR-Now","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"+vMj46eTW0BI8ANQRbnqv4Y5JH9dITXA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PERSIANN CCS","IR"],["bias","PERSIANN CCS","IR"],["bias","PERSIANN CCS","IR"]], ...

# %% [markdown]
# ### Precipitation Detection
#
# The precipitation-detection skill of all retrievals is assessed based on their ability to identify reference precipitation rates exceeding 0.1 mm h$^{-1}$. For algorithms that provide a precipitation mask or flag, this information is used to compute the probability of detection (POD), false alarm rate (FAR), and Heidke Skill Score (HSS). If an algorithm additionally provides probabilistic precipitation estimates, detection performance is further evaluated using the area under the Precision–Recall (PR) curve. For algorithms that do not provide dedicated precipitation-detection outputs, all pixels with retrieved precipitation rates exceeding 0.1 mm h$^{-1}$ are classified as raining and evaluated using POD, FAR, and HSS. Because the area under the PR curve requires probabilistic detection output, this metric cannot be computed for products that do not provide precipitation probabilities.

# %%
from satrain.baselines import DETECTION_METRICS


results = get_ranked_results(base_sensor="gmi", metrics=list(DETECTION_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="38b2eb7c-2ab1-4fb3-a9fe-645fbad4e760" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("38b2eb7c-2ab1-4fb3-a9fe-645fbad4e760")) {                    Plotly.newPlot(                        "38b2eb7c-2ab1-4fb3-a9fe-645fbad4e760",                        [{"alignmentgroup":"True","customdata":[["pod","GPROF-IR","IR"],["pod","GPROF-IR","IR"],["pod","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"YR1t3qe44j8cG4PyhuzlPwBnpYkdNeU\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PU-Net","IR"],["pod","PU-Net","IR"],["pod","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#e46f5e","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"nP5MIylM3j+o9E\u002fgIwDiP2gtGbbjTOQ\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","GPROF V07 (GMI)","PMW"],["pod","GPROF V07 (GMI)","PMW"],["pod","GPROF V07 (GMI)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (GMI)","marker":{"color":"#d24b60","pattern":{"shape":""}},"name":"GPROF V07 (GMI)","offsetgroup":"GPROF V07 (GMI)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"ckbwzuFP5z+j6mossTbnP+fMgOSytOg\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","ERA5","Reanalysis"],["pod","ERA5","Reanalysis"],["pod","ERA5","Reanalysis"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ERA5","marker":{"color":"#af3b6d","pattern":{"shape":""}},"name":"ERA5","offsetgroup":"ERA5","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"dHmUzZK32z92iIHizrvpP6P7sVgij+g\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PERSIANN CCS","IR"],["pod","PERSIANN CCS","IR"],["pod","PERSIANN CCS","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN CCS","marker":{"color":"#883171","pattern":{"shape":""}},"name":"PERSIANN CCS","offsetgroup":"PERSIANN CCS","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"vcHfk8wgyj9lpfwDQJjQP7QrR8\u002foJNA\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PERSIANN PDIR-Now","IR"],["pod","PERSIANN PDIR-Now","IR"],["pod","PERSIANN PDIR-Now","IR"]],"hovertemplate":"algori ...

# %% [markdown]
# ### Heavy Precipitation Detection
#
# The heavy-precipitation-detection skill of all retrievals is evaluated by testing their ability to identify reference precipitation rates exceeding 10 mm h$^{-1}$. The metrics are the same as for the detection of precipitation.

# %%
from satrain.baselines import HEAVY_DETECTION_METRICS
results = get_ranked_results(base_sensor="gmi", metrics=list(HEAVY_DETECTION_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="c087903d-58e2-4e54-82df-1452945cabc7" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c087903d-58e2-4e54-82df-1452945cabc7")) {                    Plotly.newPlot(                        "c087903d-58e2-4e54-82df-1452945cabc7",                        [{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF V07 (GMI)","PMW"],["pod_heavy","GPROF V07 (GMI)","PMW"],["pod_heavy","GPROF V07 (GMI)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (GMI)","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF V07 (GMI)","offsetgroup":"GPROF V07 (GMI)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA4D+GfMALoSjIP2cluDxepdA\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","PU-Net","IR"],["pod_heavy","PU-Net","IR"],["pod_heavy","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#e46f5e","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAACOCTzeBYTDPzoCymfweck\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF-IR","IR"],["pod_heavy","GPROF-IR","IR"],["pod_heavy","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#d24b60","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAABjhyjd+PO+Py2EIL9gWbE\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","PERSIANN CCS","IR"],["pod_heavy","PERSIANN CCS","IR"],["pod_heavy","PERSIANN CCS","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN CCS","marker":{"color":"#af3b6d","pattern":{"shape":""}},"name":"PERSIANN CCS","offsetgroup":"PERSIANN CCS","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA4D8d1uBGh8O5P4y2iikCNa0\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","PERSIANN PDIR-Now","IR"],["pod_heavy","PERSIANN PDIR-Now","IR"],["pod_heavy","PERSIANN PDIR-Now","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN PDIR-Now","marker":{"color":"#883171","pattern":{"shape":""}},"name":"PERSIANN PDIR-Now","offsetgroup":"PERSIANN PDIR-Now","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAAJKfSqECK0P8rSZXo8N7c\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","cu ...

# %% [markdown]
# ## Base Sensor: ATMS
#
# ### Quantitative Precipitation Estimation

# %%
from satrain.baselines import get_ranked_results, plot_baselines_interactive, QPE_METRICS

results = get_ranked_results(base_sensor="atms", metrics=list(QPE_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="73e54f8f-9694-47db-be08-431987c1630a" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("73e54f8f-9694-47db-be08-431987c1630a")) {                    Plotly.newPlot(                        "73e54f8f-9694-47db-be08-431987c1630a",                        [{"alignmentgroup":"True","customdata":[["bias","GPROF-IR","IR"],["bias","GPROF-IR","IR"],["bias","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"xNn3dCwqWkAyO4xa2T4bQEFglbsZlCbA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","ERA5","Reanalysis"],["bias","ERA5","Reanalysis"],["bias","ERA5","Reanalysis"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ERA5","marker":{"color":"#e46f5e","pattern":{"shape":""}},"name":"ERA5","offsetgroup":"ERA5","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"2AJ13xkuWkCvZQxIIin3Py2IVLfQEh7A"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","GPROF V07 (ATMS)","PMW"],["bias","GPROF V07 (ATMS)","PMW"],["bias","GPROF V07 (ATMS)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (ATMS)","marker":{"color":"#d24b60","pattern":{"shape":""}},"name":"GPROF V07 (ATMS)","offsetgroup":"GPROF V07 (ATMS)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"kWvWJ3SfZEDr47ye4Gv5v+lrt6ES0AvA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PU-Net","IR"],["bias","PU-Net","IR"],["bias","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#af3b6d","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"WLD+FPiuUUCkyrDH+pAgQAr7nIhkf\u002fk\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PERSIANN PDIR-Now","IR"],["bias","PERSIANN PDIR-Now","IR"],["bias","PERSIANN PDIR-Now","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN PDIR-Now","marker":{"color":"#883171","pattern":{"shape":""}},"name":"PERSIANN PDIR-Now","offsetgroup":"PERSIANN PDIR-Now","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"dBbiQXZhYkC7sGZvdI0LwAqHU6nilSnA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["bias","PERSIANN CCS","IR"],["bias","PERSIANN CCS","IR"],["bias","PERSIANN CCS","IR"]],"hovertem ...

# %% [markdown]
# ### Precipitation Detection

# %%
from satrain.baselines import DETECTION_METRICS

results = get_ranked_results(base_sensor="atms", metrics=list(DETECTION_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="407be9dc-1aaa-4214-83d0-112b920129cd" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("407be9dc-1aaa-4214-83d0-112b920129cd")) {                    Plotly.newPlot(                        "407be9dc-1aaa-4214-83d0-112b920129cd",                        [{"alignmentgroup":"True","customdata":[["pod","GPROF-IR","IR"],["pod","GPROF-IR","IR"],["pod","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"jPyHNUTC3j++u8H110HmP3vR3hoEtuU\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PU-Net","IR"],["pod","PU-Net","IR"],["pod","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#e46f5e","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"pPWXoMxG3D+4WPbuuR3iP+KsVpOzwOM\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","ERA5","Reanalysis"],["pod","ERA5","Reanalysis"],["pod","ERA5","Reanalysis"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ERA5","marker":{"color":"#d24b60","pattern":{"shape":""}},"name":"ERA5","offsetgroup":"ERA5","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"50YJ+sygyD+xByrIVTjqP1zsR4C0lug\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","GPROF V07 (ATMS)","PMW"],["pod","GPROF V07 (ATMS)","PMW"],["pod","GPROF V07 (ATMS)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (ATMS)","marker":{"color":"#af3b6d","pattern":{"shape":""}},"name":"GPROF V07 (ATMS)","offsetgroup":"GPROF V07 (ATMS)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"xi+0mTh\u002f5z\u002fSi0BvF+znP\u002fMDfLo88Og\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PERSIANN CCS","IR"],["pod","PERSIANN CCS","IR"],["pod","PERSIANN CCS","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN CCS","marker":{"color":"#883171","pattern":{"shape":""}},"name":"PERSIANN CCS","offsetgroup":"PERSIANN CCS","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"daFqOQsGwj8lj2i6LKHQP1\u002fkawvYNNA\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod","PERSIANN PDIR-Now","IR"],["pod","PERSIANN PDIR-Now","IR"],["pod","PERSIANN PDIR-Now","IR"]],"hovert ...

# %% [markdown]
# ### Heavy Precipitation Detection

# %%
from satrain.baselines import HEAVY_DETECTION_METRICS

results = get_ranked_results(base_sensor="atms", metrics=list(HEAVY_DETECTION_METRICS))
fig = plot_baselines_interactive(results)
display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="359d39a8-98ad-4ac2-a508-393894082a16" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("359d39a8-98ad-4ac2-a508-393894082a16")) {                    Plotly.newPlot(                        "359d39a8-98ad-4ac2-a508-393894082a16",                        [{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF V07 (ATMS)","PMW"],["pod_heavy","GPROF V07 (ATMS)","PMW"],["pod_heavy","GPROF V07 (ATMS)","PMW"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF V07 (ATMS)","marker":{"color":"#eb9872","pattern":{"shape":""}},"name":"GPROF V07 (ATMS)","offsetgroup":"GPROF V07 (ATMS)","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAABVMIWqnPi5PxiLRvdgKb4\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","PU-Net","IR"],["pod_heavy","PU-Net","IR"],["pod_heavy","PU-Net","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PU-Net","marker":{"color":"#e46f5e","pattern":{"shape":""}},"name":"PU-Net","offsetgroup":"PU-Net","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAABvuZvGjYPBP9QnFoT3W8U\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","GPROF-IR","IR"],["pod_heavy","GPROF-IR","IR"],["pod_heavy","GPROF-IR","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GPROF-IR","marker":{"color":"#d24b60","pattern":{"shape":""}},"name":"GPROF-IR","offsetgroup":"GPROF-IR","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAABAfyQGSXC5P7owwII0KLE\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","ERA5","Reanalysis"],["pod_heavy","ERA5","Reanalysis"],["pod_heavy","ERA5","Reanalysis"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ERA5","marker":{"color":"#af3b6d","pattern":{"shape":""}},"name":"ERA5","offsetgroup":"ERA5","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAACpuB8HK2N5P3vrkshJZKE\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_heavy","PERSIANN PDIR-Now","IR"],["pod_heavy","PERSIANN PDIR-Now","IR"],["pod_heavy","PERSIANN PDIR-Now","IR"]],"hovertemplate":"algorithm=%{customdata[1]}\u003cbr\u003emetric=%{customdata[0]}\u003cbr\u003edomain=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ekind=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PERSIANN PDIR-Now","marker":{"color":"#883171","pattern":{"shape":""}},"name":"PERSIANN PDIR-Now","offsetgroup":"PERSIANN PDIR-Now","orientation":"v","showlegend":true,"textposition":"auto","x":["Austria","CONUS","Korea"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAAt7MxVnvOzP4n5HT9pYLc\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pod_h ...
